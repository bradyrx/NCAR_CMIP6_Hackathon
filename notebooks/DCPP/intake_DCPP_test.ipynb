# %% [markdown]
# **Note**: I installed Anderson's `refactor` branch that is currently an open PR before running this.
#
# `pip install git+https://github.com/andersy005/intake-esm.git@refactor --upgrade`

# %%
# %matplotlib inline

import intake
import warnings
import xarray as xr

warnings.filterwarnings("ignore")

# %% [markdown]
# Note that the new command is `open_esm_datastore`, not `open_esm_metadatastore`

# %%
col = intake.open_esm_datastore("/glade/collections/cmip/catalog/intake-esm-datastore/catalogs/glade-cmip6.json")

# %%
col.df.head()
# Out:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1      day
# 1  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
# 2  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
# 3  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
# 4  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
#
#   variable_id grid_label  dcpp_init_year    version         time_range  \
# 0          pr         gn             NaN  v20190702  20150101-20551231
# 1        hfls         gn             NaN  v20190624      201501-205512
# 2        prsn         gn             NaN  v20190624      201501-205512
# 3          va         gn             NaN  v20190624      201501-205512
# 4         tas         gn             NaN  v20190624      201501-205512
#
#                                                 path
# 0  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 1  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 2  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 3  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 4  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...

# %%
col
# Out:
# glade-cmip6-ESM Collection with 687919 entries:
# 	> 12 activity_id(s)
#
# 	> 24 institution_id(s)
#
# 	> 47 source_id(s)
#
# 	> 66 experiment_id(s)
#
# 	> 162 member_id(s)
#
# 	> 35 table_id(s)
#
# 	> 1027 variable_id(s)
#
# 	> 12 grid_label(s)
#
# 	> 59 dcpp_init_year(s)
#
# 	> 246 version(s)
#
# 	> 6667 time_range(s)
#
# 	> 687919 path(s)

# %%
uniques = col.unique(columns=["activity_id", "source_id", "grid_label", "experiment_id", "table_id"])

# %%
import pprint
pprint.pprint(uniques)
# Out:
# {'activity_id': {'count': 12,
#                  'values': ['AerChemMIP',
#                             'C4MIP',
#                             'CFMIP',
#                             'CMIP',
#                             'DAMIP',
#                             'DCPP',
#                             'HighResMIP',
#                             'LS3MIP',
#                             'LUMIP',
#                             'OMIP',
#                             'PAMIP',
#                             'ScenarioMIP']},
#  'experiment_id': {'count': 66,
#                    'values': ['ssp370',
#                               'histSST-piNTCF',
#                               'histSST',
#                               'histSST-1950HC',
#                               'hist-1950HC',
#                               'hist-piNTCF',
#                               'piClim-NTCF',
#                               'ssp370SST-lowNTCF',
#                               'ssp370-lowNTCF',
#                               'ssp370SST',
#                               'hist-bgc',
#                               'esm-ssp585',
#                               'amip-future4K',
#                               'amip-m4K',
#                               'a4SST',
#                               'aqua-p4K',
#                               'piSST',
#                               'amip-4xCO2',
#                               'a4SSTice',
#                               'amip-p4K',
#                               'aqua-control',
#                               'aqua-4xCO2',
#                               'abrupt-4xCO2',
#                               'historical',
#                               'piControl',
#                               'amip',
#                               '1pctCO2',
#                               'esm-piControl',
#                               'esm-hist',
#                               'ssp245',
#                               'ssp585',
#                               'ssp126',
#                               'hist-GHG',
#                               'hist-aer',
#                               'dcppA-hindcast',
#                               'dcppC-hindcast-noPinatubo',
#                               'dcppC-hindcast-noElChichon',
#                               'dcppA-assim',
#                               'dcppC-hindcast-noAgung',
#                               'hist-1950',
#                               'highresSST-present',
#                               'control-1950',
#                               'land-hist-princeton',
#                               'land-hist-cruNcep',
#                               'land-hist',
#                               'deforest-globe',
#                               'esm-ssp585-ssp126Lu',
#                               'land-cCO2',
#                               'hist-noLu',
#                               'land-crop-noFert',
#                               'ssp370-ssp126Lu',
#                               'ssp126-ssp370Lu',
#                               'land-noLu',
#                               'land-noFire',
#                               'land-hist-altStartYear',
#                               'land-cClim',
#                               'omip1',
#                               'pdSST-piAntSIC',
#                               'pdSST-futAntSIC',
#                               'pdSST-pdSIC',
#                               'pdSST-piArcSIC',
#                               'pdSST-futArcSIC',
#                               'ssp119',
#                               'ssp434',
#                               'ssp460',
#                               'ssp534-over']},
#  'grid_label': {'count': 12,
#                 'values': ['gn',
#                            'gr',
#                            'gr1',
#                            'grz',
#                            'gnz',
#                            'gm',
#                            'gr1z',
#                            'gr2',
#                            'gr2z',
#                            'grg',
#                            'gra',
#                            'gr3']},
#  'source_id': {'count': 47,
#                'values': ['BCC-ESM1',
#                           'CESM2-WACCM',
#                           'CESM2',
#                           'CNRM-ESM2-1',
#                           'BCC-CSM2-MR',
#                           'UKESM1-0-LL',
#                           'GFDL-ESM4',
#                           'GISS-E2-1-G',
#                           'CanESM5',
#                           'CNRM-CM6-1',
#                           'FGOALS-f3-L',
#                           'FGOALS-g3',
#                           'SAM0-UNICON',
#                           'HadGEM3-GC31-LL',
#                           'HadGEM3-GC31-MM',
#                           'AWI-CM-1-1-MR',
#                           'GFDL-AM4',
#                           'GFDL-CM4',
#                           'GISS-E2-1-H',
#                           'E3SM-1-0',
#                           'CAMS-CSM1-0',
#                           'MCM-UA-1-0',
#                           'EC-Earth3-LR',
#                           'EC-Earth3',
#                           'EC-Earth3-Veg',
#                           'MRI-ESM2-0',
#                           'NESM3',
#                           'MIROC-ES2L',
#                           'MIROC6',
#                           'IPSL-CM6A-LR',
#                           'NorCPM1',
#                           'NorESM2-LM',
#                           'FIO-ESM-2-0',
#                           'CNRM-CM6-1-HR',
#                           'FGOALS-f3-H',
#                           'HadGEM3-GC31-HM',
#                           'HadGEM3-GC31-LM',
#                           'GFDL-CM4C192',
#                           'ECMWF-IFS-LR',
#                           'ECMWF-IFS-HR',
#                           'CMCC-CM2-VHR4',
#                           'CMCC-CM2-HR4',
#                           'NICAM16-7S',
#                           'NICAM16-8S',
#                           'NICAM16-9S',
#                           'IPSL-CM6A-ATM-HR',
#                           'MPI-ESM1-2-HR']},
#  'table_id': {'count': 35,
#               'values': ['day',
#                          'Amon',
#                          'AERmonZ',
#                          'CFmon',
#                          'EdayZ',
#                          'Eday',
#                          'CFday',
#                          'EmonZ',
#                          'AERday',
#                          'Emon',
#                          'fx',
#                          'Lmon',
#                          'AERmon',
#                          'Ofx',
#                          'Omon',
#                          'SImon',
#                          'Oyr',
#                          'AERhr',
#                          'Eyr',
#                          'LImon',
#                          'SIday',
#                          '6hrPlev',
#                          'CFsubhr',
#                          '6hrLev',
#                          'Oday',
#                          'ImonGre',
#                          'ImonAnt',
#                          'Efx',
#                          'IfxGre',
#                          '3hr',
#                          '6hrPlevPt',
#                          'E1hr',
#                          'E3hr',
#                          'Oclim',
#                          'CF3hr']}}

# %% [markdown]
# Pulling in DCPP output. Just a single initialization.

# %%
cat = col.search(member_id=['r7i1p2f1', 'r2i1p2f1', 'r8i1p2f1', 'r10i1p2f1'],
                 experiment_id='dcppC-hindcast-noElChichon')
dsets = cat.to_dataset_dict(cdf_kwargs={"chunks": {"time": 36}})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 1 group(s)

# %%
dsets['DCPP.CCCma.CanESM5.dcppC-hindcast-noElChichon.Amon.gn'].tas.squeeze().isel(time=0, member_id=0).plot()

# %% [markdown]
# Pulling in a more complex array here. This tests out grabbing the assimilation runs.

# %%
cat = col.search(experiment_id="dcppA-assim", institution_id='MIROC',)

# %%
cat.df
# Out:
#        activity_id institution_id source_id experiment_id  member_id table_id  \
# 563787        DCPP          MIROC    MIROC6   dcppA-assim   r2i1p1f1     Omon
# 563788        DCPP          MIROC    MIROC6   dcppA-assim   r1i1p1f1     Omon
# 563789        DCPP          MIROC    MIROC6   dcppA-assim   r3i1p1f1     Omon
# 563790        DCPP          MIROC    MIROC6   dcppA-assim   r9i1p1f1     Omon
# 563791        DCPP          MIROC    MIROC6   dcppA-assim   r8i1p1f1     Omon
# 563792        DCPP          MIROC    MIROC6   dcppA-assim  r10i1p1f1     Omon
# 563793        DCPP          MIROC    MIROC6   dcppA-assim   r7i1p1f1     Omon
# 563794        DCPP          MIROC    MIROC6   dcppA-assim   r6i1p1f1     Omon
#
#        variable_id grid_label  dcpp_init_year    version     time_range  \
# 563787         tos         gn             NaN  v20190821  195001-201712
# 563788         tos         gn             NaN  v20190821  195001-201712
# 563789         tos         gn             NaN  v20190821  195001-201712
# 563790         tos         gn             NaN  v20190821  195001-201712
# 563791         tos         gn             NaN  v20190821  195001-201712
# 563792         tos         gn             NaN  v20190821  195001-201712
# 563793         tos         gn             NaN  v20190821  195001-201712
# 563794         tos         gn             NaN  v20190821  195001-201712
#
#                                                      path
# 563787  /glade/collections/cmip/CMIP6/DCPP/MIROC/MIROC...
# 563788  /glade/collections/cmip/CMIP6/DCPP/MIROC/MIROC...
# 563789  /glade/collections/cmip/CMIP6/DCPP/MIROC/MIROC...
# 563790  /glade/collections/cmip/CMIP6/DCPP/MIROC/MIROC...
# 563791  /glade/collections/cmip/CMIP6/DCPP/MIROC/MIROC...
# 563792  /glade/collections/cmip/CMIP6/DCPP/MIROC/MIROC...
# 563793  /glade/collections/cmip/CMIP6/DCPP/MIROC/MIROC...
# 563794  /glade/collections/cmip/CMIP6/DCPP/MIROC/MIROC...

# %%
dsets = cat.to_dataset_dict(cdf_kwargs={"chunks": {"time": 36}})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 1 group(s)

# %%
# Ensemble mean over 1970-2000. Cool.
dsets['DCPP.MIROC.MIROC6.dcppA-assim.Omon.gn']['tos'].mean('member_id').sel(time=slice('1970', '2000')).mean('time').plot()

# %% [markdown]
# Now pulling in an initialized hindcast subset.

# %%
cat = col.search(experiment_id="dcppA-hindcast", table_id='Amon', member_id=['r1i1p2f1', 'r2i1p2f1'])

# %%
cat.df
# Out:
#        activity_id institution_id source_id   experiment_id member_id  \
# 562105        DCPP          CCCma   CanESM5  dcppA-hindcast  r2i1p2f1
# 562125        DCPP          CCCma   CanESM5  dcppA-hindcast  r2i1p2f1
# 562149        DCPP          CCCma   CanESM5  dcppA-hindcast  r2i1p2f1
# 562158        DCPP          CCCma   CanESM5  dcppA-hindcast  r1i1p2f1
# 562182        DCPP          CCCma   CanESM5  dcppA-hindcast  r1i1p2f1
# ...            ...            ...       ...             ...       ...
# 563163        DCPP          CCCma   CanESM5  dcppA-hindcast  r2i1p2f1
# 563183        DCPP          CCCma   CanESM5  dcppA-hindcast  r2i1p2f1
# 563190        DCPP          CCCma   CanESM5  dcppA-hindcast  r2i1p2f1
# 563242        DCPP          CCCma   CanESM5  dcppA-hindcast  r1i1p2f1
# 563260        DCPP          CCCma   CanESM5  dcppA-hindcast  r1i1p2f1
#
#        table_id variable_id grid_label  dcpp_init_year    version  \
# 562105     Amon         tas         gn          1977.0  v20190429
# 562125     Amon         tas         gn          1993.0  v20190429
# 562149     Amon         tas         gn          1971.0  v20190429
# 562158     Amon         tas         gn          2014.0  v20190429
# 562182     Amon         tas         gn          1970.0  v20190429
# ...         ...         ...        ...             ...        ...
# 563163     Amon         tas         gn          1985.0  v20190429
# 563183     Amon         tas         gn          1968.0  v20190429
# 563190     Amon         tas         gn          1981.0  v20190429
# 563242     Amon         tas         gn          2009.0  v20190429
# 563260     Amon         tas         gn          1968.0  v20190429
#
#            time_range                                               path
# 562105  197801-198712  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 562125  199401-200312  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 562149  197201-198112  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 562158  201501-202412  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 562182  197101-198012  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# ...               ...                                                ...
# 563163  198601-199512  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 563183  196901-197812  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 563190  198201-199112  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 563242  201001-201912  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 563260  196901-197812  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
#
# [87 rows x 12 columns]

# %%
dsets = cat.to_dataset_dict()
# Out:
# xarray will load netCDF datasets with dask using a single chunk for all arrays.
# For effective chunking, please provide chunks in cdf_kwargs.
# For example: cdf_kwargs={'chunks': {'time': 36}}
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 1 group(s)

# %%
# Constructed by intake-esm.
ds_intake = dsets['DCPP.CCCma.CanESM5.dcppA-hindcast.Amon.gn']['tas']

# %%
print(ds_intake)
# Out:
# <xarray.DataArray 'tas' (member_id: 2, dcpp_init_year: 53, time: 792, lat: 64, lon: 128)>
# dask.array<concatenate, shape=(2, 53, 792, 64, 128), dtype=float32, chunksize=(1, 1, 792, 64, 128), chunktype=numpy.ndarray>
# Coordinates:
#   * lon             (lon) float64 0.0 2.812 5.625 8.438 ... 351.6 354.4 357.2
#   * time            (time) object 1961-01-16 12:00:00 ... 2026-12-16 12:00:00
#   * lat             (lat) float64 -87.86 -85.1 -82.31 ... 82.31 85.1 87.86
#   * dcpp_init_year  (dcpp_init_year) float64 1.96e+03 1.961e+03 ... 2.016e+03
#   * member_id       (member_id) <U8 'r1i1p2f1' 'r2i1p2f1'
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Near-Surface Air Temperature
#     comment:        ST+273.16, DCPP_table_comment: near-surface (usually, 2 m...
#     units:          K
#     original_name:  ST
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella

# %%
ds_intake.dcpp_init_year
# Out:
# <xarray.DataArray 'dcpp_init_year' (dcpp_init_year: 52)>
# array([1960., 1961., 1962., 1963., 1964., 1965., 1966., 1967., 1968., 1969.,
#        1970., 1971., 1972., 1973., 1974., 1975., 1976., 1977., 1978., 1979.,
#        1980., 1981., 1982., 1983., 1985., 1986., 1987., 1988., 1990., 1991.,
#        1992., 1993., 1994., 1995., 1996., 1997., 1998., 1999., 2000., 2002.,
#        2003., 2004., 2006., 2007., 2008., 2009., 2010., 2011., 2012., 2013.,
#        2014., 2016.])
# Coordinates:
#   * dcpp_init_year  (dcpp_init_year) float64 1.96e+03 1.961e+03 ... 2.016e+03

# %% [markdown]
# It looks like the DCPP protocol just maintains a full time array and NaNs out irrelevant time steps with regards to that initialization year. Although I don't know what's going on in this first one.

# %%
ds_intake.isel(dcpp_init_year=0).isel(member_id=0).isel(lat=10, lon=10).load()
# Out:
# <xarray.DataArray 'tas' (time: 792)>
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#       dtype=float32)
# Coordinates:
#     dcpp_init_year  float64 1.96e+03
#     lat             float64 -60.0
#     lon             float64 28.12
#   * time            (time) object 1961-01-16 12:00:00 ... 2026-12-16 12:00:00
#     member_id       <U8 'r1i1p2f1'
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Near-Surface Air Temperature
#     comment:        ST+273.16, DCPP_table_comment: near-surface (usually, 2 m...
#     units:          K
#     original_name:  ST
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella

# %%
ds_intake.isel(dcpp_init_year=10).isel(member_id=0).isel(lat=10, lon=10).load()
# Out:
# <xarray.DataArray 'tas' (time: 792)>
# array([      nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#        274.21533, 274.80365, 274.15213, 273.27704, 272.3923 , 271.07114,
#        269.18335, 262.87296, 260.62823, 264.38748, 269.5021 , 271.75473,
#        273.3347 , 274.10553, 273.68915, 273.06635, 272.18015, 270.49902,
#        263.43277, 256.15192, 256.75854, 260.48358, 268.68698, 271.4238 ,
#        272.46408, 273.21872, 272.81396, 271.9161 , 270.67807, 270.10422,
#        261.61758, 258.70996, 254.80016, 261.0633 , 270.00662, 270.86078,
#        272.324  , 272.96097, 272.70676, 271.83856, 270.305  , 262.39127,
#        251.59093, 257.59265, 255.7802 , 263.79556, 269.14337, 270.4299 ,
#        271.63983, 272.17172, 272.4899 , 271.80948, 270.84363, 267.01172,
#        257.61682, 257.94382, 260.9115 , 264.9472 , 269.77982, 271.73874,
#        272.30936, 273.10147, 273.29492, 272.6927 , 271.93973, 270.83942,
#        261.45193, 250.3035 , 253.68431, 261.22763, 268.63202, 271.3188 ,
#        271.78638, 272.92386, 272.83496, 272.14172, 270.24292, 266.98248,
#        258.0908 , 254.93103, 258.63126, 263.85367, 269.85376, 271.38892,
#        272.4975 , 273.2981 , 272.91238, 272.57266, 270.1684 , 264.96973,
#        266.38638, 257.18948, 259.5903 , 263.8801 , 269.2809 , 270.97476,
#        272.43854, 273.26614, 272.62564, 272.02896, 271.40878, 268.90326,
#        259.05496, 255.28131, 252.61143, 260.59268, 268.44037, 271.4144 ,
#        271.89938, 272.6091 , 272.59756, 272.22137, 270.9648 , 268.2876 ,
#        265.88058, 259.00473, 256.97818, 265.4996 , 269.42026, 270.7353 ,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan],
#       dtype=float32)
# Coordinates:
#     dcpp_init_year  float64 1.97e+03
#     lat             float64 -60.0
#     lon             float64 28.12
#   * time            (time) object 1961-01-16 12:00:00 ... 2026-12-16 12:00:00
#     member_id       <U8 'r1i1p2f1'
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Near-Surface Air Temperature
#     comment:        ST+273.16, DCPP_table_comment: near-surface (usually, 2 m...
#     units:          K
#     original_name:  ST
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella

# %%
ds_intake.isel(dcpp_init_year=1).isel(member_id=0).isel(lat=10, lon=10).load()
# Out:
# <xarray.DataArray 'tas' (time: 792)>
# array([      nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#        273.56302, 273.9835 , 274.1467 , 273.30307, 272.4076 , 271.5081 ,
#        268.57938, 261.559  , 258.38507, 265.7932 , 270.51404, 271.89496,
#        273.46994, 273.77692, 273.75455, 272.92   , 271.41745, 270.9409 ,
#        264.39883, 254.72559, 253.22897, 262.75098, 268.95813, 271.27933,
#        273.0033 , 273.86252, 273.25134, 272.1653 , 270.60034, 268.16006,
#        263.4286 , 254.61638, 258.8349 , 265.18353, 267.622  , 270.15353,
#        271.7841 , 272.697  , 272.58176, 271.32642, 266.5507 , 251.81462,
#        250.63756, 252.37926, 258.97275, 264.10153, 267.46808, 270.87695,
#        271.3588 , 271.52823, 271.42825, 270.61905, 261.932  , 252.29674,
#        251.15244, 255.55725, 258.25177, 263.47006, 268.51047, 270.07083,
#        271.3544 , 272.04547, 271.89853, 271.7122 , 270.63547, 263.27676,
#        253.44185, 249.86113, 259.24356, 260.6251 , 268.48846, 271.02292,
#        271.6793 , 272.6041 , 272.3279 , 271.97247, 271.48532, 269.31497,
#        263.58975, 256.42612, 258.21503, 266.40744, 268.56805, 270.93637,
#        272.7201 , 273.10287, 273.0278 , 272.15887, 271.31992, 268.02908,
#        261.2156 , 254.197  , 262.1873 , 264.92767, 270.544  , 271.89362,
#        272.87198, 273.58936, 273.28964, 272.56476, 271.8374 , 271.09814,
#        262.60907, 258.5607 , 261.63202, 266.59747, 269.87732, 271.53302,
#        272.97952, 273.77774, 273.39478, 272.2426 , 271.1092 , 269.3866 ,
#        261.57593, 259.49478, 260.45328, 264.22183, 268.32938, 269.8635 ,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan],
#       dtype=float32)
# Coordinates:
#     dcpp_init_year  float64 1.961e+03
#     lat             float64 -60.0
#     lon             float64 28.12
#   * time            (time) object 1961-01-16 12:00:00 ... 2026-12-16 12:00:00
#     member_id       <U8 'r1i1p2f1'
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Near-Surface Air Temperature
#     comment:        ST+273.16, DCPP_table_comment: near-surface (usually, 2 m...
#     units:          K
#     original_name:  ST
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella

# %%
ds_intake.time
# Out:
# <xarray.DataArray 'time' (time: 792)>
# array([cftime.DatetimeNoLeap(1961, 1, 16, 12, 0, 0, 0, 2, 16),
#        cftime.DatetimeNoLeap(1961, 2, 15, 0, 0, 0, 0, 4, 46),
#        cftime.DatetimeNoLeap(1961, 3, 16, 12, 0, 0, 0, 5, 75), ...,
#        cftime.DatetimeNoLeap(2026, 10, 16, 12, 0, 0, 0, 4, 289),
#        cftime.DatetimeNoLeap(2026, 11, 16, 0, 0, 0, 0, 0, 320),
#        cftime.DatetimeNoLeap(2026, 12, 16, 12, 0, 0, 0, 2, 350)], dtype=object)
# Coordinates:
#   * time     (time) object 1961-01-16 12:00:00 ... 2026-12-16 12:00:00
# Attributes:
#     bounds:         time_bnds
#     axis:           T
#     long_name:      time
#     standard_name:  time

# %% [markdown]
# I think this is actually good news for `climpred`. Maybe it can expect a `init-lead` configuration or `init-target`. If this follows a `time` array then it should align exactly with the averages over the assimilation run.
